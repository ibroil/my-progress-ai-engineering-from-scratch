# %%
import numpy as np
data = np.random.randn(1000)
data.mean(), data.std()
# Out:
# (np.float64(-0.032949621013642634), np.float64(1.033127662981963))

# %% [markdown]
# $E = mc^2$

# %%
# %timeit np.random.randn(10000)
# Out:
# 96.8 μs ± 788 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# %matplotlib inline

# %%
# %env CUDA_VISIBLE_DEVICES
# Out:
# UsageError: Environment does not have key: CUDA_VISIBLE_DEVICES

# %%
# !uv pip install scikit-learn pandas
# Out:
# Using Python 3.12.13 environment at: /home/ibrok/ai-engineering-from-scratch/.venv
# Resolved 8 packages in 188ms
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)-------------------     0 B/10.39 MiB
# ⠙ Preparing packages... (0/1)------------------- 14.83 KiB/10.39 MiB
# ⠙ Preparing packages... (0/1)------------------- 30.83 KiB/10.39 MiB
# ⠙ Preparing packages... (0/1)------------------- 46.83 KiB/10.39 MiB
# ⠙ Preparing packages... (0/1)------------------- 62.83 KiB/10.39 MiB
# ⠙ Preparing packages... (0/1)------------------- 78.83 KiB/10.39 MiB
# ⠙ Preparing packages... (0/1)------------------- 94.83 KiB/10.39 MiB
# ⠙ Preparing packages... (0/1)------------------- 110.83 KiB/10.39 MiB
# ⠙ Preparing packages... (0/1)------------------- 126.83 KiB/10.39 MiB
# ⠙ Preparing packages... (0/1)------------------- 142.83 KiB/10.39 MiB
# ⠙ Preparing packages... (0/1)------------------- 158.83 KiB/10.39 MiB
# ⠙ Preparing packages... (0/1)------------------- 174.83 KiB/10.39 MiB
# ⠙ Preparing packages... (0/1)------------------- 190.83 KiB/10.39 MiB
# ⠙ Preparing packages... (0/1)------------------- 206.83 KiB/10.39 MiB
# ⠙ Preparing packages... (0/1)------------------- 222.83 KiB/10.39 MiB
# ⠙ Preparing packages... (0/1)------------------- 238.83 KiB/10.39 MiB
# ⠙ Preparing packages... (0/1)------------------- 254.83 KiB/10.39 MiB
# ⠙ Preparing packages... (0/1)------------------- 2.59 MiB/10.39 MiB
# ⠙ Preparing packages... (0/1)30m------------ 6.35 MiB/10.39 MiB
# ⠙ Preparing packages... (0/1)---------- 7.78 MiB/10.39 MiB
# ⠹ Preparing packages... (0/1)---------- 8.82 MiB/10.39 MiB
# Prepared 1 package in 261ms
# Installed 1 package in 24ms
#  + pandas==3.0.3

# %%
import pandas as pd

df = pd.DataFrame({
    "model": ["Linear", "Random Forest", "Neural Net"],
    "accuracy": [0.72, 0.89, 0.94],
    "training_time": [0.1, 2.3, 45.6]
})
df
# Out:
#            model  accuracy  training_time
# 0         Linear      0.72            0.1
# 1  Random Forest      0.89            2.3
# 2     Neural Net      0.94           45.6

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 4))
plt.plot([1, 2, 3, 4], [1, 4, 2, 3])
plt.title("Inline Plot")
plt.show()
